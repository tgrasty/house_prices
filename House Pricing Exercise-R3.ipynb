# %% [markdown]
# # Kaggle competition: Predicting House Prices 202003

# %%
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import KFold
from sklearn.metrics import mean_squared_log_error
import statsmodels.api as sm
from statsmodels.formula.api import ols
from sklearn.preprocessing import StandardScaler
from pydoc import help
from scipy.stats.stats import pearsonr
from statsmodels.stats.multicomp import pairwise_tukeyhsd
from statsmodels.stats.multicomp import MultiComparison
from scipy.stats.stats import kendalltau

# %%
def correlated_variables(data,obj_variable,min_corr=0.6):
    """
    Generates a DataFrame with the correlations and variables that are higher than "min_corr" for variable selection.
    data: DataFrame. Correlation matrix only for numeric variables and including objective variable.
    min_corr: int. Minimum correlation that will be selected as high correlated
    obj_variable: string. Name of the objective variable for the model
    """
    high_corr = pd.DataFrame(columns=['Variable1','Variable2','Corr_V1&V2','Corr_V1&Obj','Corr_V2&Obj'])
    k=0
    obj_var_pos = data.columns.get_loc(obj_variable)
    for i in range(0,len(data)):
        for j in range(k,len(data)):
            if(data.iloc[i,j]>=min_corr and data.iloc[i,j]!=1 and j!=obj_var_pos):
                a = data.index[i]
                b = data.columns[j]
                c = data.iloc[i,j]
                d = data.iloc[i,obj_var_pos]
                e = data.iloc[j,obj_var_pos]
                high_corr = high_corr.append(pd.DataFrame([[a,b,c,d,e]],columns=high_corr.columns))
        k+=1
    return high_corr.sort_values('Corr_V1&V2',ascending=False)

# %%
def null_info(df):
    null_count = df.isna().sum().to_frame()
    null_count.columns = ['#_NA'] 
    null_count['%'] = null_count*100/len(df)
    #null_count[null_count['%']>30].sort_values('%',ascending=False)
    df_dtypes = df.dtypes.to_frame()
    df_dtypes.columns = ['data_type']
    return null_count.merge(df_dtypes,how='left',left_on=null_count.index,right_on=df_dtypes.index).sort_values('%',ascending=False)

# %%
#Generate 'Empty' category for categorical variables and fill with 0 numerical ones
def fill_missing_values(data):
    """
    Fill missing values with category 'Empty' for categorical variables and 0 for numerical
    Data: DataFrame. Contains the data that will be analyzed
    """
    df1 = data.copy()
    for i in df1:
        if df1[i].dtypes == 'object': 
            #print('Transforming column: ',i,'\n')
            df1[i].fillna('Empty',inplace=True)
        else:
            df1[i].fillna(0,inplace=True)
    return df1

# %%
def integrate_dummies(data,key):
    """Generates data set ready for applying a machine learning algorithm: sepparates the object variables, gets the dummie 
    variables and returns a data frame with all the features.
    data: pandas data frame, only contains the features that will be used for the machine learning algorithm
    key: pandas series, column that contains primary key of the dataset
    """
    is_object = data.dtypes==object
    numeric_features = [i for i in is_object.index if is_object[i]==False]
    object_features = [i for i in is_object.index if is_object[i]==True]
    dummies = pd.get_dummies(data[object_features],drop_first=True)
    dummies['key'] = key
    #dummies['key']=df_1.rut_deudor.astype(str)+df_1.rut_cliente.astype(str)
    numeric_df = data.loc[:,numeric_features]
    numeric_df['key'] = key
    return pd.merge(left=numeric_df,right=dummies, how='inner', on='key').drop('key',axis=1)

# %%
from sklearn.utils import check_array
def mean_absolute_percentage_error(y_true, y_pred): 
    """
    Returns the mean absolute percentage error
    y_true: 1d array. Real values of "y"
    y_pred: 1d array. Predicted values of "y"
    """
    #y_true, y_pred = check_array(y_true, y_pred)

    ## Note: does not handle mix 1d representation
    #if _is_1d(y_true): 
    #    y_true, y_pred = _check_1d_array(y_true, y_pred)

    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
def pearson_filtering(data,obj_variable,max_pvalue=0.05,min_pearson=0.5):
    """
    Returns DataFrame with the pearson correlation and p-values for numerical variables of "data" with a higher correlation than "threshold" with the "obj_variable"
    data: Data Frame containing numerical and categorical variables as well as the objective variable
    max_pvalue: float/int. Maximum pvalue for numeric variables correlation
    min_pearson: float/int. Minimum pearson correlation between the regressor variables and objective variable ("obj_variable")
    obj_variable: string. Name of the objective variable within "data"
    """
    data_corr = data.loc[:,data.dtypes!='object'].corr()
    selected_numerical = data_corr[data_corr[obj_variable].abs()>min_pearson][obj_variable]
    try:
        selected_numerical.drop([obj_variable],inplace=True)
    except (KeyError):
        pass

    #Calculate P-values and filtering significant variables (<5%)
    pearson_stats = [pearsonr(data[i].to_numpy(),data[obj_variable]) for i in data[selected_numerical.index]]
    result = pd.DataFrame(pearson_stats,columns=['Corr_Coef','P-value'],index=selected_numerical.index)
    return result[result['P-value']<max_pvalue].sort_values('Corr_Coef',ascending=False)

# %%
path = 'C:/Users/tgrasty/Desktop/DS/Otros/1. House Prices/train.csv'

# %%
df = pd.read_csv(path)

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
# 2   2008        WD         Normal     223500
# 3   2006        WD        Abnorml     140000
# 4   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %%
df.shape
# Out:
# (1460, 81)

# %%
pd.set_option('display.max_rows', 100)

# %%
# Check data types
sample = df.head().transpose()
types = df.dtypes.to_frame()
types.merge(sample,how='left',left_on=types.index,right_on=sample.index)
# Out:
#             key_0      0_x      0_y        1        2        3        4
# 0              Id    int64        1        2        3        4        5
# 1      MSSubClass    int64       60       20       60       70       60
# 2        MSZoning   object       RL       RL       RL       RL       RL
# 3     LotFrontage  float64       65       80       68       60       84
# 4         LotArea    int64     8450     9600    11250     9550    14260
# 5          Street   object     Pave     Pave     Pave     Pave     Pave
# 6           Alley   object      NaN      NaN      NaN      NaN      NaN
# 7        LotShape   object      Reg      Reg      IR1      IR1      IR1
# 8     LandContour   object      Lvl      Lvl      Lvl      Lvl      Lvl
# 9       Utilities   object   AllPub   AllPub   AllPub   AllPub   AllPub
# 10      LotConfig   object   Inside      FR2   Inside   Corner      FR2
# 11      LandSlope   object      Gtl      Gtl      Gtl      Gtl      Gtl
# 12   Neighborhood   object  CollgCr  Veenker  CollgCr  Crawfor  NoRidge
# 13     Condition1   object     Norm    Feedr     Norm     Norm     Norm
# 14     Condition2   object     Norm     Norm     Norm     Norm     Norm
# 15       BldgType   object     1Fam     1Fam     1Fam     1Fam     1Fam
# 16     HouseStyle   object   2Story   1Story   2Story   2Story   2Story
# 17    OverallQual    int64        7        6        7        7        8
# 18    OverallCond    int64        5        8        5        5        5
# 19      YearBuilt    int64     2003     1976     2001     1915     2000
# 20   YearRemodAdd    int64     2003     1976     2002     1970     2000
# 21      RoofStyle   object    Gable    Gable    Gable    Gable    Gable
# 22       RoofMatl   object  CompShg  CompShg  CompShg  CompShg  CompShg
# 23    Exterior1st   object  VinylSd  MetalSd  VinylSd  Wd Sdng  VinylSd
# 24    Exterior2nd   object  VinylSd  MetalSd  VinylSd  Wd Shng  VinylSd
# 25     MasVnrType   object  BrkFace     None  BrkFace     None  BrkFace
# 26     MasVnrArea  float64      196        0      162        0      350
# 27      ExterQual   object       Gd       TA       Gd       TA       Gd
# 28      ExterCond   object       TA       TA       TA       TA       TA
# 29     Foundation   object    PConc   CBlock    PConc   BrkTil    PConc
# 30       BsmtQual   object       Gd       Gd       Gd       TA       Gd
# 31       BsmtCond   object       TA       TA       TA       Gd       TA
# 32   BsmtExposure   object       No       Gd       Mn       No       Av
# 33   BsmtFinType1   object      GLQ      ALQ      GLQ      ALQ      GLQ
# 34     BsmtFinSF1    int64      706      978      486      216      655
# 35   BsmtFinType2   object      Unf      Unf      Unf      Unf      Unf
# 36     BsmtFinSF2    int64        0        0        0        0        0
# 37      BsmtUnfSF    int64      150      284      434      540      490
# 38    TotalBsmtSF    int64      856     1262      920      756     1145
# 39        Heating   object     GasA     GasA     GasA     GasA     GasA
# 40      HeatingQC   object       Ex       Ex       Ex       Gd       Ex
# 41     CentralAir   object        Y        Y        Y        Y        Y
# 42     Electrical   object    SBrkr    SBrkr    SBrkr    SBrkr    SBrkr
# 43       1stFlrSF    int64      856     1262      920      961     1145
# 44       2ndFlrSF    int64      854        0      866      756     1053
# 45   LowQualFinSF    int64        0        0        0        0        0
# 46      GrLivArea    int64     1710     1262     1786     1717     2198
# 47   BsmtFullBath    int64        1        0        1        1        1
# 48   BsmtHalfBath    int64        0        1        0        0        0
# 49       FullBath    int64        2        2        2        1        2
# 50       HalfBath    int64        1        0        1        0        1
# 51   BedroomAbvGr    int64        3        3        3        3        4
# 52   KitchenAbvGr    int64        1        1        1        1        1
# 53    KitchenQual   object       Gd       TA       Gd       Gd       Gd
# 54   TotRmsAbvGrd    int64        8        6        6        7        9
# 55     Functional   object      Typ      Typ      Typ      Typ      Typ
# 56     Fireplaces    int64        0        1        1        1        1
# 57    FireplaceQu   object      NaN       TA       TA       Gd       TA
# 58     GarageType   object   Attchd   Attchd   Attchd   Detchd   Attchd
# 59    GarageYrBlt  float64     2003     1976     2001     1998     2000
# 60   GarageFinish   object      RFn      RFn      RFn      Unf      RFn
# 61     GarageCars    int64        2        2        2        3        3
# 62     GarageArea    int64      548      460      608      642      836
# 63     GarageQual   object       TA       TA       TA       TA       TA
# 64     GarageCond   object       TA       TA       TA       TA       TA
# 65     PavedDrive   object        Y        Y        Y        Y        Y
# 66     WoodDeckSF    int64        0      298        0        0      192
# 67    OpenPorchSF    int64       61        0       42       35       84
# 68  EnclosedPorch    int64        0        0        0      272        0
# 69      3SsnPorch    int64        0        0        0        0        0
# 70    ScreenPorch    int64        0        0        0        0        0
# 71       PoolArea    int64        0        0        0        0        0
# 72         PoolQC   object      NaN      NaN      NaN      NaN      NaN
# 73          Fence   object      NaN      NaN      NaN      NaN      NaN
# 74    MiscFeature   object      NaN      NaN      NaN      NaN      NaN
# 75        MiscVal    int64        0        0        0        0        0
# 76         MoSold    int64        2        5        9        2       12
# 77         YrSold    int64     2008     2007     2008     2006     2008
# 78       SaleType   object       WD       WD       WD       WD       WD
# 79  SaleCondition   object   Normal   Normal   Normal  Abnorml   Normal
# 80      SalePrice    int64   208500   181500   223500   140000   250000

# %% [markdown]
# ### Data Cleansing

# %%
df_nulls = null_info(df)
df_nulls
#df_nulls[df_nulls['%']>0].sort_values('%',ascending=False)
# Out:
#             key_0  #_NA          % data_type
# 72         PoolQC  1453  99.520548    object
# 74    MiscFeature  1406  96.301370    object
# 6           Alley  1369  93.767123    object
# 73          Fence  1179  80.753425    object
# 57    FireplaceQu   690  47.260274    object
# 3     LotFrontage   259  17.739726   float64
# 59    GarageYrBlt    81   5.547945   float64
# 64     GarageCond    81   5.547945    object
# 58     GarageType    81   5.547945    object
# 60   GarageFinish    81   5.547945    object
# 63     GarageQual    81   5.547945    object
# 35   BsmtFinType2    38   2.602740    object
# 32   BsmtExposure    38   2.602740    object
# 30       BsmtQual    37   2.534247    object
# 31       BsmtCond    37   2.534247    object
# 33   BsmtFinType1    37   2.534247    object
# 26     MasVnrArea     8   0.547945   float64
# 25     MasVnrType     8   0.547945    object
# 42     Electrical     1   0.068493    object
# 0              Id     0   0.000000     int64
# 55     Functional     0   0.000000    object
# 56     Fireplaces     0   0.000000     int64
# 53    KitchenQual     0   0.000000    object
# 52   KitchenAbvGr     0   0.000000     int64
# 51   BedroomAbvGr     0   0.000000     int64
# 50       HalfBath     0   0.000000     int64
# 49       FullBath     0   0.000000     int64
# 48   BsmtHalfBath     0   0.000000     int64
# 54   TotRmsAbvGrd     0   0.000000     int64
# 61     GarageCars     0   0.000000     int64
# 46      GrLivArea     0   0.000000     int64
# 62     GarageArea     0   0.000000     int64
# 65     PavedDrive     0   0.000000    object
# 66     WoodDeckSF     0   0.000000     int64
# 67    OpenPorchSF     0   0.000000     int64
# 68  EnclosedPorch     0   0.000000     int64
# 69      3SsnPorch     0   0.000000     int64
# 70    ScreenPorch     0   0.000000     int64
# 71       PoolArea     0   0.000000     int64
# 75        MiscVal     0   0.000000     int64
# 76         MoSold     0   0.000000     int64
# 77         YrSold     0   0.000000     int64
# 78       SaleType     0   0.000000    object
# 79  SaleCondition     0   0.000000    object
# 47   BsmtFullBath     0   0.000000     int64
# 40      HeatingQC     0   0.000000    object
# 45   LowQualFinSF     0   0.000000     int64
# 11      LandSlope     0   0.000000    object
# 17    OverallQual     0   0.000000     int64
# 16     HouseStyle     0   0.000000    object
# 15       BldgType     0   0.000000    object
# 14     Condition2     0   0.000000    object
# 13     Condition1     0   0.000000    object
# 12   Neighborhood     0   0.000000    object
# 10      LotConfig     0   0.000000    object
# 19      YearBuilt     0   0.000000     int64
# 9       Utilities     0   0.000000    object
# 8     LandContour     0   0.000000    object
# 7        LotShape     0   0.000000    object
# 5          Street     0   0.000000    object
# 4         LotArea     0   0.000000     int64
# 2        MSZoning     0   0.000000    object
# 18    OverallCond     0   0.000000     int64
# 20   YearRemodAdd     0   0.000000     int64
# 44       2ndFlrSF     0   0.000000     int64
# 36     BsmtFinSF2     0   0.000000     int64
# 43       1stFlrSF     0   0.000000     int64
# 41     CentralAir     0   0.000000    object
# 1      MSSubClass     0   0.000000     int64
# 39        Heating     0   0.000000    object
# 38    TotalBsmtSF     0   0.000000     int64
# 37      BsmtUnfSF     0   0.000000     int64
# 34     BsmtFinSF1     0   0.000000     int64
# 21      RoofStyle     0   0.000000    object
# 29     Foundation     0   0.000000    object
# 28      ExterCond     0   0.000000    object
# 27      ExterQual     0   0.000000    object
# 24    Exterior2nd     0   0.000000    object
# 23    Exterior1st     0   0.000000    object
# 22       RoofMatl     0   0.000000    object
# 80      SalePrice     0   0.000000     int64

# %%
df1 = fill_missing_values(df)

# %%
df1_nulls = null_info(df1)
df1_nulls[df1_nulls['%']>0].sort_values('%',ascending=False)
# Out:
# Empty DataFrame
# Columns: [key_0, #_NA, %, data_type]
# Index: []

# %% [markdown]
# #### Correction of data types

# %%
df1['CentralAir'].unique()
# Out:
# array(['Y', 'N'], dtype=object)

# %%
#CentralAir -> transform to binary
df1['CentralAir'] = df1['CentralAir'].map(lambda x: 1 if x=='Y' else 0)

# %%
#Correct current numeric variables that represent categories: transform to string
to_string = ['MSSubClass','YearBuilt','YearRemodAdd','GarageYrBlt','MoSold','YrSold']
new_categorical = df1[to_string].astype(str)
df1.drop(to_string,axis=1,inplace=True)
df1 = pd.concat([df1,new_categorical],axis=1)

# %%
df1.MSSubClass.dtypes
# Out:
# dtype('O')

# %% [markdown]
# ###  Variable Generation

# %%
df1['TotalArea'] = df1.PoolArea+df1.LotArea+df1.GrLivArea+df1.GarageArea

# %%
#features_subset = df.loc[:,['Neighborhood','TotalArea','OveralQual','HeatingQC','CentralAir','SaleCondition']]
df1['TotalLivingArea'] = df1['1stFlrSF']+df1['2ndFlrSF']

# %% [markdown]
# ### Standardization

# %%
df1.shape
# Out:
# (1460, 83)

# %%
numerical_variables = [i for i in df1 if df1[i].dtypes!=object and i!="Id"]
standard_df1 = (df1[numerical_variables]-df1[numerical_variables].mean())/df1[numerical_variables].std()
df2 = df1.drop(numerical_variables,axis=1)
df2 = pd.concat([df2,standard_df1],axis=1)
df2.head()
#scaler = StandardScaler() 
#data_scaled = scaler.fit_transform(df1)
# Out:
#    Id MSZoning Street  Alley LotShape LandContour Utilities LotConfig  \
# 0   1       RL   Pave  Empty      Reg         Lvl    AllPub    Inside
# 1   2       RL   Pave  Empty      Reg         Lvl    AllPub       FR2
# 2   3       RL   Pave  Empty      IR1         Lvl    AllPub    Inside
# 3   4       RL   Pave  Empty      IR1         Lvl    AllPub    Corner
# 4   5       RL   Pave  Empty      IR1         Lvl    AllPub       FR2
#
#   LandSlope Neighborhood  ... WoodDeckSF OpenPorchSF EnclosedPorch 3SsnPorch  \
# 0       Gtl      CollgCr  ...  -0.751918    0.216429     -0.359202 -0.116299
# 1       Gtl      Veenker  ...   1.625638   -0.704242     -0.359202 -0.116299
# 2       Gtl      CollgCr  ...  -0.751918   -0.070337     -0.359202 -0.116299
# 3       Gtl      Crawfor  ...  -0.751918   -0.175988      4.091122 -0.116299
# 4       Gtl      NoRidge  ...   0.779930    0.563567     -0.359202 -0.116299
#
#   ScreenPorch  PoolArea   MiscVal SalePrice TotalArea TotalLivingArea
# 0   -0.270116 -0.068668 -0.087658  0.347154 -0.176801        0.384487
# 1   -0.270116 -0.068668 -0.087658  0.007286 -0.116493       -0.475128
# 2   -0.270116 -0.068668 -0.087658  0.535970  0.111576        0.530315
# 3   -0.270116 -0.068668 -0.087658 -0.515105 -0.058837        0.397919
# 4   -0.270116 -0.068668 -0.087658  0.869545  0.470083        1.320854
#
# [5 rows x 83 columns]

# %% [markdown]
# ### Variable Selection

# %%
df2.loc[:,df2.dtypes!='object'].shape
# Out:
# (1460, 35)

# %% [markdown]
# #### Filtering numerical variables: Pearson correlation

# %%
selected_numerical = pearson_filtering(df2,'SalePrice',max_pvalue=0.05,min_pearson=0.4)
# Out:
# C:\Users\tgrasty\Anaconda3\lib\site-packages\pandas\core\generic.py:3783: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(obj)

# %%
selected_numerical
# Out:
#                  Corr_Coef        P-value
# OverallQual       0.790982  2.185675e-313
# TotalLivingArea   0.716883  1.183941e-230
# GrLivArea         0.708624  4.518034e-223
# GarageCars        0.640409  2.498644e-169
# GarageArea        0.623431  5.265038e-158
# TotalBsmtSF       0.613581  9.484229e-152
# 1stFlrSF          0.605852  5.394711e-147
# FullBath          0.560664  1.236470e-121
# TotRmsAbvGrd      0.533723  2.772281e-108
# MasVnrArea        0.472614   4.100461e-82
# Fireplaces        0.466929   6.141487e-80

# %%
#Check correlation
a = pd.DataFrame(data=selected_numerical.index)
b = pd.DataFrame([['SalePrice']],columns=a.columns)
correlation = df2[a.append(b).iloc[:,0]].corr()
correlation
# Out:
#                  OverallQual  TotalLivingArea  GrLivArea  GarageCars  \
# OverallQual         1.000000         0.600758   0.593007    0.600671
# TotalLivingArea     0.600758         1.000000   0.995718    0.479932
# GrLivArea           0.593007         0.995718   1.000000    0.467247
# GarageCars          0.600671         0.479932   0.467247    1.000000
# GarageArea          0.562022         0.479189   0.468997    0.882475
# TotalBsmtSF         0.537808         0.461738   0.454868    0.434585
# 1stFlrSF            0.476224         0.572041   0.566024    0.439317
# FullBath            0.550600         0.635296   0.630012    0.469672
# TotRmsAbvGrd        0.427452         0.820088   0.825489    0.362289
# SalePrice           0.790982         0.716883   0.708624    0.640409
#
#                  GarageArea  TotalBsmtSF  1stFlrSF  FullBath  TotRmsAbvGrd  \
# OverallQual        0.562022     0.537808  0.476224  0.550600      0.427452
# TotalLivingArea    0.479189     0.461738  0.572041  0.635296      0.820088
# GrLivArea          0.468997     0.454868  0.566024  0.630012      0.825489
# GarageCars         0.882475     0.434585  0.439317  0.469672      0.362289
# GarageArea         1.000000     0.486665  0.489782  0.405656      0.337822
# TotalBsmtSF        0.486665     1.000000  0.819530  0.323722      0.285573
# 1stFlrSF           0.489782     0.819530  1.000000  0.380637      0.409516
# FullBath           0.405656     0.323722  0.380637  1.000000      0.554784
# TotRmsAbvGrd       0.337822     0.285573  0.409516  0.554784      1.000000
# SalePrice          0.623431     0.613581  0.605852  0.560664      0.533723
#
#                  SalePrice
# OverallQual       0.790982
# TotalLivingArea   0.716883
# GrLivArea         0.708624
# GarageCars        0.640409
# GarageArea        0.623431
# TotalBsmtSF       0.613581
# 1stFlrSF          0.605852
# FullBath          0.560664
# TotRmsAbvGrd      0.533723
# SalePrice         1.000000

# %% [markdown]
# #### Filtering categorical variables: one hot encoding + Pearson correlation

# %%
selected_categorical = df2.loc[:,df2.dtypes == 'object']
#selected_categorical = pd.concat([selected_categorical,df2['SalePrice']],axis=1)

# %%
dummies = pd.get_dummies(selected_categorical.iloc[:,:],drop_first=True)

# %%
dummies = pd.concat([dummies,df2['SalePrice']],axis=1)

# %%
selected_categorical = pearson_filtering(dummies,'SalePrice',max_pvalue=0.05,min_pearson=0.4)
selected_categorical
# Out:
# C:\Users\tgrasty\Anaconda3\lib\site-packages\pandas\core\generic.py:3783: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(obj)
#                       Corr_Coef        P-value
# BsmtQual_Ex            0.553105  9.157709e-118
# Foundation_PConc       0.497734   3.124704e-92
# ExterQual_Gd           0.452466   1.380858e-74
# BsmtFinType1_GLQ       0.434597   2.544986e-68
# GarageFinish_Fin       0.419678   2.274204e-63
# Neighborhood_NridgHt   0.402149   7.301451e-58
# GarageFinish_Unf      -0.410608   1.765710e-60
# BsmtQual_TA           -0.452394   1.466790e-74
# KitchenQual_TA        -0.519298  1.285609e-101
# ExterQual_TA          -0.589044  4.309567e-137

# %% [markdown]
# #### Filtering categorical variables: one hot encoding + linear regression coeficient´s significance

# %%
# Discarded because the coefficients depend on the amount of variables selected for the regression. It was not clear 
# wheather it was correct to iteratively consider one variable at a time

# %%
#selected_categorical = df2.loc[:,df2.dtypes == 'object']
#dummies = pd.get_dummies(selected_categorical.iloc[:,:],drop_first=True)
#X2 = sm.add_constant(dummies)
#est = sm.OLS(df2['SalePrice'], X2)
#est2 = est.fit()
#results_as_html = est2.summary().tables[1].as_html()

#lm_results = pd.read_html(results_as_html, header=0, index_col=0)[0]
#lm_results
#lm_results.sort_values('P>|t|',ascending=True)

# %% [markdown]
# #### Filtering categorical variables: Kendall’s tau correlation

# %%
# Kendall´s correlation is discarded: because Kendall´s tau is designed for "ordinal association", 
# which is not the case here for categorical variables and also because it doesn´t measure the "magnitude" or "strength" of
# the association between the variables, but just whether they are in the same order or not.

# %%
#selected_categorical = df2.loc[:,df2.dtypes == 'object']
#selected_categorical = pd.concat([selected_categorical,df2['SalePrice']],axis=1)

# Null hypothesis for Kendall Tau test is absence of association
#kendall_corr = pd.DataFrame(index=selected_categorical.columns,columns=['kendall_corr','p-value'])
#j = 0
#for i in selected_categorical:
#    result = kendalltau(selected_categorical.loc[:,i],df2['SalePrice'])
#    kendall_corr.iloc[j,0] = result.correlation
#    kendall_corr.iloc[j,1] = result.pvalue
#    j+=1
#kendall_corr[kendall_corr['p-value']<0.05].sort_values('kendall_corr',ascending=False)

# %% [markdown]
# #### Filtering categorical variables: ANOVA

# %%
# ANOVA is discarded: the assumption of the distribution of the error is not met.

# %%
#selected_categorical = df1.loc[:,df2.dtypes=='object']
#selected_categorical = pd.concat([selected_categorical,df2['SalePrice']],axis=1)

#mod = ols('SalePrice ~ LotShape',data=selected_categorical).fit()

##To test normality of errors execute the following:
##import scipy.stats as stats
##stats.shapiro(mod.resid)

#aov_table = sm.stats.anova_lm(mod, typ=2)
#print(aov_table)

# Post hoc test
#mc = MultiComparison(df2['SalePrice'], df['LotShape'])
#mc_results = mc.tukeyhsd()
#print(mc_results)

# %% [markdown]
# ### Correlation and Integration

# %%
# Join selected variables

#Generate list of unique original variable names
a = list(set([i.split('_')[0] for i in selected_categorical.index]))

b = [i for i in selected_numerical.index]
c = ['SalePrice']
total_selected = a+b+c
total_selected
# Out:
# ['ExterQual',
#  'Neighborhood',
#  'BsmtQual',
#  'GarageFinish',
#  'KitchenQual',
#  'BsmtFinType1',
#  'Foundation',
#  'OverallQual',
#  'TotalLivingArea',
#  'GrLivArea',
#  'GarageCars',
#  'GarageArea',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  'FullBath',
#  'TotRmsAbvGrd',
#  'MasVnrArea',
#  'Fireplaces',
#  'SalePrice']

# %%
a = pd.concat([df2[total_selected],df2['Id']],axis=1)
df3 = integrate_dummies(a,a['Id'])
df3
# Out:
#       OverallQual  TotalLivingArea  GrLivArea  GarageCars  GarageArea  \
# 0        0.651256         0.384487   0.370207    0.311618    0.350880
# 1       -0.071812        -0.475128  -0.482347    0.311618   -0.060710
# 2        0.651256         0.530315   0.514836    0.311618    0.631510
# 3        0.651256         0.397919   0.383528    1.649742    0.790533
# 4        1.374324         1.320854   1.298881    1.649742    1.697903
# 5       -0.794879        -0.283249  -0.292045    0.311618    0.032833
# 6        1.374324         0.353787   0.339758    0.311618    0.762470
# 7        0.651256         1.113625   1.093354    0.311618    0.051542
# 8        0.651256         0.507290   0.492000    0.311618   -0.023293
# 9       -0.794879        -0.830103  -0.834405   -1.026506   -1.253387
# 10      -0.794879        -0.901098  -0.904817   -1.026506   -0.416175
# 11       2.097391         1.562621   1.538661    1.649742    1.230187
# 12      -0.794879        -1.146702  -1.148404   -1.026506   -0.565844
# 13       0.651256        -0.029970  -0.040846    1.649742    1.716612
# 14      -0.071812        -0.492397  -0.499474   -1.026506   -0.565844
# 15       0.651256        -1.257991  -1.258779    0.311618    0.481841
# 16      -0.071812        -0.970174  -0.973326    0.311618    0.032833
# 17      -1.517947        -0.409889  -0.417644    0.311618    0.201211
# 18      -0.794879        -0.759108  -0.763994    0.311618    0.481841
# 19      -0.794879        -0.327381  -0.335814   -1.026506   -0.837119
# 20       1.374324         1.662397   1.637618    1.649742    1.777415
# 21       0.651256        -0.770620  -0.775412   -1.026506   -0.902599
# 22       1.374324         0.547584   0.531963    0.311618    0.285400
# 23      -0.794879        -0.862722  -0.866757    0.311618    0.463132
# 24      -0.794879        -0.862722  -0.866757   -1.026506   -0.949371
# 25       1.374324         0.173421   0.160874    1.649742    1.950470
# 26      -0.794879        -1.169727  -1.171240    0.311618    0.481841
# 27       1.374324         0.372975   0.358788    1.649742    1.398565
# 28      -0.794879         0.173421   0.160874   -1.026506   -0.720190
# 29      -1.517947        -1.898865  -1.894388   -1.026506   -1.089686
# 30      -1.517947        -0.369595  -0.377681   -1.026506   -1.042914
# 31      -0.794879        -0.540366  -0.547049   -1.026506   -0.944694
# 32       1.374324        -0.528854  -0.535631    0.311618    0.051542
# 33      -0.794879         0.365300   0.351176    0.311618   -0.121513
# 34       2.097391         0.098589   0.086657    0.311618    0.388297
# 35       1.374324         1.808225   1.782248    1.649742    1.019714
        b = pre_selection.loc[i,'Corr_V2&Obj']
        if a>=b:
            result.append(pre_selection.loc[i,'Variable1'])
        else:
            result.append(pre_selection.loc[i,'Variable2'])
result
# Out:
# ['GarageCars',
#  'GrLivArea',
#  'TotalLivingArea',
#  'TotalBsmtSF',
#  'Foundation_Slab',
#  'KitchenQual_TA',
#  'TotalLivingArea',
#  'GrLivArea',
#  'ExterQual_Gd',
#  'OverallQual',
#  'OverallQual']

# %% [markdown]
# ## Transformation

# %% [markdown]
# ## Modeling

# %%
x_train,x_test,y_train,y_test = train_test_split(df3.drop(['SalePrice','Id'],axis=1),df3['SalePrice'], test_size=0.33)

# %%
model = LinearRegression()

#Standardize x_train
std_x_train = (x_train[numerical_variables]-df1[numerical_variables].mean())/df1[numerical_variables].std()

model.fit(x_train, y_train)
score = model.score(x_test, y_test)
y_pred = np.maximum(model.predict(x_test),np.full(len(x_test),0))
print('R^2: ',score)
print('Mean Absolute Error (MAE): ',metrics.mean_absolute_error(y_pred,y_test))
print('Root Mean Square Error (RMSE):', np.sqrt(metrics.mean_squared_error(y_pred,y_test)))
print('Mean Absolute Percentage Error (MAPE): ',mean_absolute_percentage_error(y_test,y_pred),'%')
print('Root Mean Square Logarithmic Error (RMSLE): ',np.sqrt(metrics.mean_squared_log_error(y_test,y_pred)))
# Out:
# R^2:  -4.602530826003815e+16
# Mean Absolute Error (MAE):  15086801.3631799
# Root Mean Square Error (RMSE): 110116673.9836079
# Mean Absolute Percentage Error (MAPE):  3470308093.4219217 %
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-80-7ca723f9bc97> in <module>
#       7 print('Root Mean Square Error (RMSE):', np.sqrt(metrics.mean_squared_error(y_pred,y_test)))
#       8 print('Mean Absolute Percentage Error (MAPE): ',mean_absolute_percentage_error(y_test,y_pred),'%')
# ----> 9 print('Root Mean Square Logarithmic Error (RMSLE): ',np.sqrt(metrics.mean_squared_log_error(y_test,y_pred)))
#
# ~\Anaconda3\lib\site-packages\sklearn\metrics\regression.py in mean_squared_log_error(y_true, y_pred, sample_weight, multioutput)
#     312
#     313     if (y_true < 0).any() or (y_pred < 0).any():
# --> 314         raise ValueError("Mean Squared Logarithmic Error cannot be used when "
#     315                          "targets contain negative values.")
#     316
#
# ValueError: Mean Squared Logarithmic Error cannot be used when targets contain negative values.

# %%
#model.intercept_
#model.coef_

# %%
results = pd.DataFrame({'y_pred':y_pred[:],'y_test':y_test[:]})
results.head(10)

# %%
# Train Using Stats Model
X = x_train
y = y_train

X2 = sm.add_constant(X)
est = sm.OLS(y, X2)
est2 = est.fit()
results_as_html = est2.summary().tables[1].as_html()

# %%
# Display results
lm_results = pd.read_html(results_as_html, header=0, index_col=0)[0]
lm_results.sort_values('P>|t|',ascending=True)

# %%
#Validate OLS coef of determination (R**2)
model.score(x_train,y_train)

# %% [markdown]
# ### Decision Tree

# %%
#tree = DecisionTreeClassifier(#class_weight=None, criterion='gini', max_depth=4,max_features=None, max_leaf_nodes=None,
                       #min_impurity_decrease=0.0, min_impurity_split=None,
                       #min_samples_leaf=200, min_samples_split=2,
                       #min_weight_fraction_leaf=0.0, presort=False,
                       #random_state=123, splitter='best'
                    )
#classifier = tree.fit(x_train,y_train)
#predictions = classifier.predict(x_test)
#accuracy_score(y_true = y_test, y_pred = predictions)
